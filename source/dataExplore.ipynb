# %%
import pandas as pd
import numpy as np
import data

# %% [markdown]
# # Master.csv

# %% [markdown]
# idx： 每笔贷款的unique key， 可与另外2个⽂件里的idx相匹配。
#
# UserInfo_*： 借款⼈特征字段
#
# WeblogInfo_*： Info⽹络⾏为字段
#
# Education_Info*： 学历学籍字段
#
# ThirdParty_Info_PeriodN_*： 第三⽅数据时间段N字段
#
# SocialNetwork_*： 社交⽹络字段
#
# LinstingInfo： 借款成交时间
#
# Target： 违约标签（1 = 贷款违约， 0 = 正常还款） 。 测试集里不包含target字段。

# %%
train_master_frame,test_master_frame=data.loadMaterFrame()

# %%
train_master_frame.head(10)
# Out:
#      Idx  UserInfo_1 UserInfo_2  UserInfo_3 UserInfo_4  WeblogInfo_1  \
# 0  10001         1.0         深圳         4.0         深圳           NaN
# 1  10002         1.0         温州         4.0         温州           NaN
# 2  10003         1.0         宜昌         3.0         宜昌           NaN
# 3  10006         4.0         南平         1.0         南平           NaN
# 4  10007         5.0         辽阳         1.0         辽阳           NaN
# 5  10008         1.0         吴忠         5.0         银川           NaN
# 6  10011         1.0         绵阳         3.0         赤峰           NaN
# 7  10015         4.0         东莞         5.0         东莞           NaN
# 8  10019         1.0         赤峰         6.0         赤峰           NaN
# 9  10021         3.0         武汉         5.0         鄂州           NaN
#
#    WeblogInfo_2  WeblogInfo_3  WeblogInfo_4  WeblogInfo_5     ...       \
# 0           1.0           NaN           1.0           1.0     ...
# 1           0.0           NaN           1.0           1.0     ...
# ...

# %%
test_master_frame.head(10)
# Out:
#      Idx  UserInfo_1 UserInfo_2  UserInfo_3 UserInfo_4  WeblogInfo_1  \
# 0  10005         1.0         广州         5.0         韶关           NaN
# 1  10013         4.0         郴州         6.0         广州           NaN
# 2  10020         3.0         惠州         5.0         惠州           NaN
# 3  10033         1.0         枣庄         6.0         枣庄           NaN
# 4  10035         4.0         深圳         5.0         南平           NaN
# 5  10038         1.0         济宁         3.0         济宁           NaN
# 6   1004         5.0        连云港         5.0        连云港           NaN
# 7  10042         4.0         德州         3.0         德州           NaN
# 8  10043         3.0         青岛         6.0         聊城           NaN
# 9  10046         4.0         深圳         5.0         汕尾           NaN
#
#    WeblogInfo_2  WeblogInfo_3  WeblogInfo_4  WeblogInfo_5     ...       \
# 0           0.0           NaN           1.0           1.0     ...
# 1           0.0           NaN           1.0           1.0     ...
# ...
